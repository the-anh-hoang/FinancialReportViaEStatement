# %%
import pandas as pd

# %%
data = pd.read_csv('Data/Result/output.csv')

# %%
data.head()
# Out:
#    Date                                     Description Withdrawals($)
# 0   NaN                 ContactlessInteracpurchase-6532          13.81
# 1   NaN                  ContactlessInteracTransit-2378           3.15
# 2   NaN  ContactlessInteracTransit-8485 TLNK/0450773780         101.91
# 3   NaN   ContactlessInteracpurchase-0525 TIMHORTONS#29          95.24
# 4   NaN                 ContactlessInteracpurchase-7168           2.84
